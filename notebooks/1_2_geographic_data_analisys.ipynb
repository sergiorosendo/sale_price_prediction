# %% [markdown]
# #### Imports

# %%
import sys
sys.path.append('..')

# %% [markdown]
# #### Read data

# %%
import pandas as pd

df = pd.read_csv('../data/house_sales.csv')
df.drop_duplicates(inplace=True)
print('%d houses' % df.shape[0])
# Out:
# 18445 houses

# %% [markdown]
# ## Geographic exploration
#
# To get a feel for the data's behavior let us examine the impact of the house's geographical features on its price.

# %% [markdown]
# ### Location

# %%
from src.visualization.visualize import plot_location

plot_location(df)

# %% [markdown]
# Higher latitudes,  tend to have more expensive properties, possibly indicating that the north region is more valued by buyers.
#
# In a horizontal line the importance seems to be in the propertie's distance to a margin, not so much in the longitude. Margins of blank areas, which possibly are water or green regions, frequently (but not always) have pricier homes.

# %% [markdown]
# ### Waterfront Status

# %%
from src.visualization.visualize import plot_waterfront

plot_waterfront(df)

# %% [markdown]
# Being waterfront tends to make for much more expensive homes, which helps to confirm the location graph.
#
# ### Zip Codes

# %%
from src.visualization.visualize import plot_zip_codes

plot_zip_codes(df)

# %% [markdown]
# There is a noticeable difference between price quantiles for different zip codes. Possibly indicating the relevance of of the localization and of the neighborhood for the house value.
#
# There are 70 different zip codes represented in the data set.
